# %%
X=[10, 20, 30, 35, 40, 45]
y=[5, 9, 10, 11, 10, 11]

# %%
import matplotlib.pyplot as plt
plt.xlim([0, 60])
plt.ylim([0, 60])
plt.scatter(X, y)

# %%
def line(w, b, x=X):
    y_predict -[]
    for xi in x:
        y_predict.append(w*xi+b)

# %%
def loss(w, b, X=x):
